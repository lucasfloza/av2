# %% [markdown]
# # Questão

# %% [markdown]
# ![alt text](q1.png)

# %% [markdown]
# # Diagrama

# %%
pip install mermaid-py
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mermaid as md
from mermaid.graph import Graph

render = md.Mermaid("""
graph TD
    A[Start] --> B[Define is_prime function]
    B --> C[Define find_primes function]
    C --> D[Call find_primes300]
    D --> E[Print results]
    
    %% is_prime function
    subgraph is_prime
        F[Check if num < 2] -->|Yes| G[Return False]
        F -->|No| H[Loop i from 2 to sqrt num]
        H --> I{num % i == 0?}
        I -->|Yes| J[Return False]
        I -->|No| K[Continue Loop]
        K --> H
        H -->|Loop Done| L[Return True]
    end
    
    %% find_primes function
    subgraph find_primes
        M[Initialize empty primes list] --> N[Set number = 2]
        N --> O{len primes < quantity?}
        O -->|Yes| P[Check if number is prime]
        P -->|Yes| Q[Add to primes list]
        Q --> R[Increment number]
        R --> O
        P -->|No| R
        O -->|No| S[Return primes list]
    end
    
    %% Print results
    E --> T[Format and print each prime number]
    T --> U[End]
""")
render
# Out:
#         <div class="mermaid-4f6584f1-2626-429b-8ba9-d82bd414e9b4"></div>
#         <script type="module">
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.1.0/+esm'
# ...

# %% [markdown]
# # Código

# %%
def is_prime(num):
    """Check if a number is prime"""
    if num < 2:
        return False
    for i in range(2, int(num ** 0.5) + 1):
        if num % i == 0:
            return False
    return True

def find_primes(quantity):
    """Find a specific quantity of prime numbers"""
    primes = []
    number = 2

    while len(primes) < quantity:
        if is_prime(number):
            primes.append(number)
        number += 1

    return primes

# Find the first 300 prime numbers
first_300_primes = find_primes(300)

# Print the numbers with formatting
print("The first 300 prime numbers are:")
for i, prime in enumerate(first_300_primes, 1):
    print(f"{i:3d}º prime: {prime:4d}")
# Out:
# Os 300 primeiros números primos são:
#   1º primo:    2
#   2º primo:    3
#   3º primo:    5
#   4º primo:    7
#   5º primo:   11
#   6º primo:   13
#   7º primo:   17
#   8º primo:   19
#   9º primo:   23
#  10º primo:   29
#  11º primo:   31
#  12º primo:   37
#  13º primo:   41
#  14º primo:   43
#  15º primo:   47
#  16º primo:   53
#  17º primo:   59
#  18º primo:   61
#  19º primo:   67
#  20º primo:   71
#  21º primo:   73
#  22º primo:   79
#  23º primo:   83
#  24º primo:   89
#  25º primo:   97
#  26º primo:  101
#  27º primo:  103
#  28º primo:  107
#  29º primo:  109
#  30º primo:  113
#  31º primo:  127
#  32º primo:  131
#  33º primo:  137
#  34º primo:  139
#  35º primo:  149
#  36º primo:  151
#  37º primo:  157
#  38º primo:  163
#  39º primo:  167
#  40º primo:  173
#  41º primo:  179
#  42º primo:  181
#  43º primo:  191
#  44º primo:  193
#  45º primo:  197
#  46º primo:  199
#  47º primo:  211
#  48º primo:  223
#  49º primo:  227
#  50º primo:  229
# ...
