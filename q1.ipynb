# %% [markdown]
# # Questão

# %% [markdown]
# ![alt text](q1.png)

# %% [markdown]
# # Diagrama

# %%
pip install mermaid-py
# Out:
# Collecting mermaid-py
#   Downloading mermaid_py-0.8.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting requests<3.0.0,>=2.31.0 (from mermaid-py)
#   Downloading requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3.0.0,>=2.31.0->mermaid-py)
#   Downloading charset_normalizer-3.4.2-cp313-cp313-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0,>=2.31.0->mermaid-py)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.31.0->mermaid-py)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3.0.0,>=2.31.0->mermaid-py)
#   Downloading certifi-2025.6.15-py3-none-any.whl.metadata (2.4 kB)
# Downloading mermaid_py-0.8.0-py3-none-any.whl (31 kB)
# Downloading requests-2.32.4-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.2-cp313-cp313-win_amd64.whl (105 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading certifi-2025.6.15-py3-none-any.whl (157 kB)
# Installing collected packages: urllib3, idna, charset_normalizer, certifi, requests, mermaid-py
#
#    ---------------------------------------- 0/6 [urllib3]
#    ---------------------------------------- 0/6 [urllib3]
#    ---------------------------------------- 0/6 [urllib3]
#    ---------------------------------------- 0/6 [urllib3]
#    ------ --------------------------------- 1/6 [idna]
#    ------------- -------------------------- 2/6 [charset_normalizer]
#    ------------- -------------------------- 2/6 [charset_normalizer]
#    -------------------------- ------------- 4/6 [requests]
#    -------------------------- ------------- 4/6 [requests]
#    --------------------------------- ------ 5/6 [mermaid-py]
#    --------------------------------- ------ 5/6 [mermaid-py]
#    --------------------------------- ------ 5/6 [mermaid-py]
#    ---------------------------------------- 6/6 [mermaid-py]
#
# Successfully installed certifi-2025.6.15 charset_normalizer-3.4.2 idna-3.10 mermaid-py-0.8.0 requests-2.32.4 urllib3-2.5.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\casa\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import mermaid as md
from mermaid.graph import Graph

render = md.Mermaid("""
graph TD
    A[Start] --> B[Define is_prime function]
    B --> C[Define find_primes function]
    C --> D[Call find_primes300]
    D --> E[Print results]
    
    %% is_prime function
    subgraph is_prime
        F[Check if num < 2] -->|Yes| G[Return False]
        F -->|No| H[Loop i from 2 to sqrt num]
        H --> I{num % i == 0?}
        I -->|Yes| J[Return False]
        I -->|No| K[Continue Loop]
        K --> H
        H -->|Loop Done| L[Return True]
    end
    
    %% find_primes function
    subgraph find_primes
        M[Initialize empty primes list] --> N[Set number = 2]
        N --> O{len primes < quantity?}
        O -->|Yes| P[Check if number is prime]
        P -->|Yes| Q[Add to primes list]
        Q --> R[Increment number]
        R --> O
        P -->|No| R
        O -->|No| S[Return primes list]
    end
    
    %% Print results
    E --> T[Format and print each prime number]
    T --> U[End]
""")
render
# Out:
# <svg id="mermaid-svg" width="100%" xmlns="http://www.w3.org/2000/svg" class="flowchart" style="max-width: 1517.22265625px;" viewBox="0 0 1517.22265625 1642.984375" role="graphics-document document" aria-roledescription="flowchart-v2" xmlns:xlink="http://www.w3.org/1999/xlink"><style xmlns="http://www.w3.org/1999/xhtml">@import url("https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.7.2/css/all.min.css");</style><style>#mermaid-svg{font-family:"trebuchet ms",verdana,arial,sans-serif;font-size:16px;fill:#333;}@keyframes edge-animation-frame{from{stroke-dashoffset:0;}}@keyframes dash{to{stroke-dashoffset:0;}}#mermaid-svg .edge-animation-slow{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 50s linear infinite;stroke-linecap:round;}#mermaid-svg .edge-animation-fast{stroke-dasharray:9,5!important;stroke-dashoffset:900;animation:dash 20s linear infinite;stroke-linecap:round;}#mermaid-svg .error-icon{fill:#552222;}#mermaid-svg .error-text{fill:#552222;stroke:#552222;}#mermaid-svg .edge-thickness-normal{stroke-width:1px;}#mermaid-svg .edge-thickness-thick{stroke-width:3.5px;}#mermaid-svg .edge-pattern-solid{stroke-dasharray:0;}#mermaid-svg .edge-thickness-invisible{stroke-width:0;fill:none;}#mermaid-svg .edge-pattern-dashed{stroke-dasharray:3;}#mermaid-svg .edge-pattern-dotted{stroke-dasharray:2;}#mermaid-svg .marker{fill:#333333;stroke:#333333;}#mermaid-svg .marker.cross{stroke:#333333;}#mermaid-svg svg{font-family:"trebuchet ms",verdana,arial,sans-serif;font-size:16px;}#mermaid-svg p{margin:0;}#mermaid-svg .label{font-family:"trebuchet ms",verdana,arial,sans-serif;color:#333;}#mermaid-svg .cluster-label text{fill:#333;}#mermaid-svg .cluster-label span{color:#333;}#mermaid-svg .cluster-label span p{background-color:transparent;}#mermaid-svg .label text,#mermaid-svg span{fill:#333;color:#333;}#mermaid-svg .node rect,#mermaid-svg .node circle,#mermaid-svg .node ellipse,#mermaid-svg .node polygon,#mermaid-svg .node path{fill:#ECECFF;stroke:#9370DB;stroke-width:1px;}#mermaid-svg .rough-node .label text,#mermaid-svg .node .label text,#mermaid-svg .image-shape .label,#mermaid-svg .icon-shape .label{text-anchor:middle;}#mermaid-svg .node .katex path{fill:#000;stroke:#000;stroke-width:1px;}#mermaid-svg .rough-node .label,#mermaid-svg .node .label,#mermaid-svg .image-shape .label,#mermaid-svg .icon-shape .label{text-align:center;}#mermaid-svg .node.clickable{cursor:pointer;}#mermaid-svg .root .anchor path{fill:#333333!important;stroke-width:0;stroke:#333333;}#mermaid-svg .arrowheadPath{fill:#333333;}#mermaid-svg .edgePath .path{stroke:#333333;stroke-width:2.0px;}#mermaid-svg .flowchart-link{stroke:#333333;fill:none;}#mermaid-svg .edgeLabel{background-color:rgba(232,232,232, 0.8);text-align:center;}#mermaid-svg .edgeLabel p{background-color:rgba(232,232,232, 0.8);}#mermaid-svg .edgeLabel rect{opacity:0.5;background-color:rgba(232,232,232, 0.8);fill:rgba(232,232,232, 0.8);}#mermaid-svg .labelBkg{background-color:rgba(232, 232, 232, 0.5);}#mermaid-svg .cluster rect{fill:#ffffde;stroke:#aaaa33;stroke-width:1px;}#mermaid-svg .cluster text{fill:#333;}#mermaid-svg .cluster span{color:#333;}#mermaid-svg div.mermaidTooltip{position:absolute;text-align:center;max-width:200px;padding:2px;font-family:"trebuchet ms",verdana,arial,sans-serif;font-size:12px;background:hsl(80, 100%, 96.2745098039%);border:1px solid #aaaa33;border-radius:2px;pointer-events:none;z-index:100;}#mermaid-svg .flowchartTitleText{text-anchor:middle;font-size:18px;fill:#333;}#mermaid-svg rect.text{fill:none;stroke-width:0;}#mermaid-svg .icon-shape,#mermaid-svg .image-shape{background-color:rgba(232,232,232, 0.8);text-align:center;}#mermaid-svg .icon-shape p,#mermaid-svg .image-shape p{background-color:rgba(232,232,232, 0.8);padding:2px;}#mermaid-svg .icon-shape rect,#mermaid-svg .image-shape rect{opacity:0.5;background-color:rgba(232,232,232, 0.8);fill:rgba(232,232,232, 0.8);}#mermaid-svg :root{--mermaid-font-family:"trebuchet ms",verdana,arial,sans-serif;}</sty ...

# %% [markdown]
# # Código

# %%
def is_prime(num):
    """Check if a number is prime"""
    if num < 2:
        return False
    for i in range(2, int(num ** 0.5) + 1):
        if num % i == 0:
            return False
    return True

def find_primes(quantity):
    """Find a specific quantity of prime numbers"""
    primes = []
    number = 2

    while len(primes) < quantity:
        if is_prime(number):
            primes.append(number)
        number += 1

    return primes

# Find the first 300 prime numbers
first_300_primes = find_primes(300)

# Print the numbers with formatting
print("The first 300 prime numbers are:")
for i, prime in enumerate(first_300_primes, 1):
    print(f"{i:3d}º prime: {prime:4d}")
# Out:
# The first 300 prime numbers are:
#   1º prime:    2
#   2º prime:    3
#   3º prime:    5
#   4º prime:    7
#   5º prime:   11
#   6º prime:   13
#   7º prime:   17
#   8º prime:   19
#   9º prime:   23
#  10º prime:   29
#  11º prime:   31
#  12º prime:   37
#  13º prime:   41
#  14º prime:   43
#  15º prime:   47
#  16º prime:   53
#  17º prime:   59
#  18º prime:   61
#  19º prime:   67
#  20º prime:   71
#  21º prime:   73
#  22º prime:   79
#  23º prime:   83
#  24º prime:   89
#  25º prime:   97
#  26º prime:  101
#  27º prime:  103
#  28º prime:  107
#  29º prime:  109
#  30º prime:  113
#  31º prime:  127
#  32º prime:  131
#  33º prime:  137
#  34º prime:  139
#  35º prime:  149
#  36º prime:  151
#  37º prime:  157
#  38º prime:  163
#  39º prime:  167
#  40º prime:  173
#  41º prime:  179
#  42º prime:  181
#  43º prime:  191
#  44º prime:  193
#  45º prime:  197
#  46º prime:  199
#  47º prime:  211
#  48º prime:  223
#  49º prime:  227
#  50º prime:  229
#  51º prime:  233
#  52º prime:  239
#  53º prime:  241
#  54º prime:  251
#  55º prime:  257
#  56º prime:  263
#  57º prime:  269
#  58º prime:  271
#  59º prime:  277
#  60º prime:  281
#  61º prime:  283
#  62º prime:  293
#  63º prime:  307
#  64º prime:  311
#  65º prime:  313
#  66º prime:  317
#  67º prime:  331
#  68º prime:  337
#  69º prime:  347
#  70º prime:  349
#  71º prime:  353
#  72º prime:  359
#  73º prime:  367
#  74º prime:  373
#  75º prime:  379
#  76º prime:  383
#  77º prime:  389
#  78º prime:  397
#  79º prime:  401
#  80º prime:  409
#  81º prime:  419
#  82º prime:  421
#  83º prime:  431
#  84º prime:  433
#  85º prime:  439
#  86º prime:  443
#  87º prime:  449
#  88º prime:  457
#  89º prime:  461
#  90º prime:  463
#  91º prime:  467
#  92º prime:  479
#  93º prime:  487
#  94º prime:  491
#  95º prime:  499
#  96º prime:  503
#  97º prime:  509
#  98º prime:  521
#  99º prime:  523
# 100º prime:  541
# 101º prime:  547
# 102º prime:  557
# 103º prime:  563
# 104º prime:  569
# 105º prime:  571
# 106º prime:  577
# 107º prime:  587
# 108º prime:  593
# 109º prime:  599
# 110º prime:  601
# 111º prime:  607
# 112º prime:  613
# 113º prime:  617
# 114º prime:  619
# 115º prime:  631
# 116º prime:  641
# 117º prime:  643
# 118º prime:  647
# 119º prime:  653
# 120º prime:  659
# 121º prime:  661
# 122º prime:  673
# 123º prime:  677
# 124º prime:  683
# 125º prime:  691
# 126º prime:  701
# 127º prime:  709
# 128º prime:  719
# 129º prime:  727
# 130º prime:  733
# 131º prime:  739
# 132º prime:  743
# 133º prime:  751
# 134º prime:  757
# 135º prime:  761
# 136º prime:  769
# 137º prime:  773
# 138º prime:  787
# 139º prime:  797
# 140º prime:  809
# 141º prime:  811
# 142º prime:  821
# 143º prime:  823
# 144º prime:  827
